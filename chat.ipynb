# %% [markdown]
# ### Sample Chat app with python and LangChain.
#
# **this process includes following requirements.**
#
# 1. installation on ollama model *RUN:* `ollama run llama3.2:1b`
# 2. create your virtual env. *RUN:* `pipenv shell`
# 3. install langchain library. *RUN:* `pipenv install langchain`

# %%
from langchain import agent
